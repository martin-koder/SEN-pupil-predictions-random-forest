# %%
import pandas as pd

# %%
df=pd.read_csv('sen_school_level_underlying_data (1).csv')# import schools dataset

# %%
postcode_df=pd.read_csv('ukpostcodes.csv')#import postcode datset

# %%
postcode_df
# Out:
#               id  postcode   latitude  longitude
# 0              1  AB10 1XG  57.144165  -2.114848
# 1              2  AB10 6RN  57.137880  -2.121487
# 2              3  AB10 7JB  57.124274  -2.127190
# 3              4  AB11 5QN  57.142701  -2.093295
# 4              5  AB11 6UL  57.137547  -2.112233
# ...          ...       ...        ...        ...
# 1769494  2668230   YO7 3GA  54.153881  -1.423284
# 1769495  2668231   YO7 9BR  54.232597  -1.328747
# 1769496  2668232   YO7 9BS  54.232597  -1.328747
# 1769497  2668233   YO8 4FD  53.782053  -1.073703
# 1769498  2668234   YO8 9UG  53.771516  -1.157536
#
# [1769499 rows x 4 columns]

# %%
postcode_df.rename(columns={'postcode': 'school_postcode'}, inplace=True)#rename column so it can be used for merging

# %%
postcode_df.head()
# Out:
#    id school_postcode   latitude  longitude
# 0   1        AB10 1XG  57.144165  -2.114848
# 1   2        AB10 6RN  57.137880  -2.121487
# 2   3        AB10 7JB  57.124274  -2.127190
# 3   4        AB11 5QN  57.142701  -2.093295
# 4   5        AB11 6UL  57.137547  -2.112233

# %%
postcode_df.drop(['id'], axis=1)#remove redundant column
# Out:
#         school_postcode   latitude  longitude
# 0              AB10 1XG  57.144165  -2.114848
# 1              AB10 6RN  57.137880  -2.121487
# 2              AB10 7JB  57.124274  -2.127190
# 3              AB11 5QN  57.142701  -2.093295
# 4              AB11 6UL  57.137547  -2.112233
# ...                 ...        ...        ...
# 1769494         YO7 3GA  54.153881  -1.423284
# 1769495         YO7 9BR  54.232597  -1.328747
# 1769496         YO7 9BS  54.232597  -1.328747
# 1769497         YO8 4FD  53.782053  -1.073703
# 1769498         YO8 9UG  53.771516  -1.157536
#
# [1769499 rows x 3 columns]

# %%
sch_lat_lon_df=pd.merge(df, postcode_df)#merge dataframes

# %%
sch_lat_lon_df.head()
# Out:
#    time_period time_identifier geographic_level country_code country_name  \
# 0       201920   Academic year           School    E92000001      England
# 1       201920   Academic year           School    E92000001      England
# 2       201920   Academic year           School    E92000001      England
# 3       201920   Academic year           School    E92000001      England
# 4       201920   Academic year           School    E92000001      England
#
#   region_code region_name  old_la_code new_la_code         la_name  ...  \
# 0   E12000007      London          201   E09000001  City of London  ...
# 1   E12000007      London          201   E09000001  City of London  ...
# 2   E12000007      London          201   E09000001  City of London  ...
# 3   E12000007      London          201   E09000001  City of London  ...
# 4   E12000007      London          201   E09000001  City of London  ...
#
#    prov_vi  prov_msi prov_pd  prov_asd prov_oth SEN_Unit RP_Unit       id  \
# ...

# %%
sch_lat_lon_df.shape#check shape
# Out:
# (24304, 78)

# %%
sch_lat_lon_df.to_csv('sch_lat_lon_df.csv')#save file

# %% [markdown]
# Below is an earlier attempt to use geocoding which was abadoned in favour of the simpler solution above

# %% [raw]
# from geopy.extra.rate_limiter import RateLimiter
# from geopy.geocoders import Nominatim
# locator = Nominatim(user_agent='myGeocoder')
#
# # 1 - conveneint function to delay between geocoding calls
# geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# # 2- - create location column
# df_test['location'] = df_test['school_postcode'].apply(geocode)
# # # 3 - create longitude, laatitude and altitude from location column (returns tuple)
# df_test['point'] = df_test['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# # 4 - split point column into latitude, longitude and altitude columns
# df_test[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df_test['point'].tolist(), index=df_test.index)

# %%
df_test
# Out:
#     time_period time_identifier geographic_level country_code country_name  \
# 0        201920   Academic year           School    E92000001      England
# 1        201920   Academic year           School    E92000001      England
# 2        201920   Academic year           School    E92000001      England
# 3        201920   Academic year           School    E92000001      England
# 4        201920   Academic year           School    E92000001      England
# 5        201920   Academic year           School    E92000001      England
# 6        201920   Academic year           School    E92000001      England
# 7        201920   Academic year           School    E92000001      England
# 8        201920   Academic year           School    E92000001      England
# 9        201920   Academic year           School    E92000001      England
# 10       201920   Academic year           School    E92000001      England
# ...
